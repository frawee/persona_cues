# %%
from ast import literal_eval
import itertools 
import json
import os
import random
import re

import datasets
from loguru import logger
import pandas as pd

# %%
with open('hf_token.txt', 'r') as f:
    hf_token = f.read().strip()

# %% [markdown]
# # Socio-Demographic Data

# %%
n_samples = 5
# do not change seed here to ensure that most unique values are present in the combinations
random.seed(13)

age_group_unique = ['18-34', '35-54', '55+']
ethnicity_unique = ['White', 'Asian', 'Hispanic', 'Black']
gender_unique = ['Female', 'Male', 'Non-binary']

combinations = {
    'gender': [('18-34', 'White'), ('18-34', 'Asian'), ('18-34', 'Hispanic'), ('35-54', 'White'), ('35-54', 'Asian')],
    'ethnicity': random.sample(list(itertools.product(gender_unique[:2], age_group_unique)), k=n_samples),
    'age_group': random.sample(list(itertools.product(ethnicity_unique, gender_unique[:2])), k=n_samples),
}

# %%
def prep_dfs(df, var, combinations, unique_vals, n_samples: int=5):
    dfs = []
    group_vals = [x for x in combinations.keys() if x != var]
    for group in combinations[var]:
        group_df = df.loc[
            ((df[group_vals[0]]==group[0]) | 
            (df[group_vals[0]]==group[1])) &
            ((df[group_vals[1]]==group[0]) | 
            (df[group_vals[1]]==group[1]))
        ]
        dfs.append([])
        for val in unique_vals:
            sub_df = group_df.loc[group_df[var] == val]
            if len(sub_df) >= n_samples:
                dfs[-1].append(sub_df)
            else:
                raise ValueError(f'No samples for {var}={val} in group {group}')
    return dfs

def sample_conversations(df_list, n_samples=5):
    random.seed(13)
    assert n_samples <= len(df_list), 'n_samples exceeds number of sublists'
    conversations = {'gender': [], 'ethnicity': [], 'age_group': [], 'text': []}
    sampled_sublists = random.sample(range(len(df_list)), k=n_samples)
    for i in sampled_sublists:
        sublist = df_list[i]
        for sub_df in sublist:
            row = sub_df.iloc[random.sample(range(len(sub_df)), k=1)].to_dict(orient='records')[0]
            conversations['gender'].append(row['gender'])
            conversations['ethnicity'].append(row['ethnicity'])
            conversations['age_group'].append(row['age_group'])
            conversations['text'].append(row['text'])

    return conversations

# %%
data = {}

# %% [markdown]
# ## PRISM conversations
# human-written user conversations
# https://proceedings.neurips.cc/paper_files/paper/2024/file/be2e1b68b44f2419e19f6c35a1b8cf35-Paper-Datasets_and_Benchmarks_Track.pdf

# %%
d1 = datasets.load_dataset('HannahRoseKirk/prism-alignment', 'conversations')['train']
d2 = datasets.load_dataset('HannahRoseKirk/prism-alignment', 'survey')['train']

age_map = {
    '18-24 years old': '18-34',
    '25-34 years old': '18-34',
    '35-44 years old': '35-54',
    '45-54 years old': '35-54',
    '55-64 years old': '55+',
    '65+ years old': '55+',
    'Prefer not to say': 'Prefer not to say'
}
gender_map = {
    'Male': 'Male', 
    'Female': 'Female',
    'Prefer not to say': None,
    'Non-binary / third gender': 'Non-binary'
}

user_ids_survey = d2['user_id']
age_groups = [age_map[a] for a in list(d2['age'])]
genders = [gender_map[a] for a in list(d2['gender'])]
ethnicities = [dict(e)['simplified'] for e in list(d2['ethnicity'])] 
demographics = list(zip(user_ids_survey, age_groups, genders, ethnicities))

user_ids_conversations = d1['user_id']
conversations = []
for d in d1['conversation_history']:
    c = [{'role': di['role'] if di['role'] != 'model' else 'assistant', 'content': di['content']} for di in d if di['if_chosen'] != False]
    seen = set()
    c =  [ci for ci in c if ci['role'] == 'user' or ((key_c := ci['content']) not in seen and not seen.add(key_c))]
    conversations.append(c)

prism_df = pd.DataFrame({'user_id': user_ids_conversations, 'text': conversations})
prism_df = prism_df.merge(pd.DataFrame(demographics, columns=['user_id', 'age_group', 'gender', 'ethnicity']))
prism_df = prism_df.loc[(prism_df['age_group'].isin(age_group_unique)) &
                        (prism_df['ethnicity'].isin(ethnicity_unique)) &
                        (prism_df['gender'].isin(gender_unique))]

# %%
data['writing-style-human'] = {}

gender_dfs = prep_dfs(df=prism_df, var='gender', combinations=combinations, unique_vals=gender_unique)    
gender_conversations = sample_conversations(df_list=gender_dfs, n_samples=5) 
data['writing-style-human']['gender'] = gender_conversations

ethnicity_dfs = prep_dfs(df=prism_df, var='ethnicity', combinations=combinations, unique_vals=ethnicity_unique)    
ethnicity_conversations = sample_conversations(df_list=ethnicity_dfs, n_samples=5) 
data['writing-style-human']['ethnicity'] = ethnicity_conversations

age_group_dfs = prep_dfs(df=prism_df, var='age_group', combinations=combinations, unique_vals=age_group_unique)    
age_group_conversations = sample_conversations(df_list=age_group_dfs, n_samples=5)
data['writing-style-human']['age_group'] = age_group_conversations

# %%
age_group_conversations
# Out:
# {'gender': ['Male',
#   'Male',
#   'Male',
#   'Female',
#   'Female',
#   'Female',
#   'Male',
#   'Male',
#   'Male',
#   'Female',
#   'Female',
#   'Female',
#   'Female',
#   'Female',
#   'Female'],
#  'ethnicity': ['White',
#   'White',
#   'White',
#   'Hispanic',
#   'Hispanic',
#   'Hispanic',
#   'Hispanic',
#   'Hispanic',
#   'Hispanic',
#   'Asian',
#   'Asian',
#   'Asian',
#   'Black',
#   'Black',
#   'Black'],
#  'age_group': ['18-34',
#   '35-54',
#   '55+',
#   '18-34',
#   '35-54',
#   '55+',
#   '18-34',
#   '35-54',
#   '55+',
#   '18-34',
#   '35-54',
#   '55+',
#   '18-34',
#   '35-54',
#   '55+'],
#  'text': [[{'role': 'user', 'content': 'Give me a recipe using cumcumber'},
#    {'role': 'assistant',
#     'content': 'Here is a 50 word recipe using cucumber:\n\nSlice cucumbers and toss with 2 tbsp olive oil, 2 tbsp lemon juice, 1 tsp minced garlic, 1/4 tsp salt, and freshly ground black pepper. Let marinate 15 minutes. Serve over salad greens or enjoy as a healthy side dish. Fresh and tasty!'},
#    {'role': 'user',
#     'content': 'Can you give an alternative witout lemon juice ?'},
#    {'role': 'assistant',
#     'content': 'Here is a 50 word cucumber recipe without lemon juice:\n\nSlice cucumbers and toss with 2 tbsp olive oil, 2 tsp white wine vinegar, 1 tsp minced garlic, 1/4 tsp dried dill, 1/4 tsp salt, and freshly ground black pepper. Let marinate 15 minutes. Serve over salad greens or enjoy as a refreshing cucumber salad side dish.'},
#    {'role': 'user',
#     'content': 'Can you explain me if the recipe is good for my health ?'},
#    {'role': 'assistant',
#     'content': 'Here is a 50 word explanation on if the cucumber recipe is healthy:\n\nYes, this cucumber salad recipe is very healthy. Cucumbers are low in calories and full of nutrients like vitamin K, vitamin C, magnesium, and potassium. The olive oil provides healthy fats. Vinegar adds tang without calories or fat. Garlic and dill offer additional nutrients and flavor. This light, fresh salad makes an excellent healthy side dish.'},
#    {'role': 'user',
#     'content': 'Do not limit the explanation in terms of number of words'},
#    {'role': 'assistant',
#     'content': "Sure, I'm happy to provide a more detailed explanation without a word limit on why this cucumber salad recipe is healthy:\n\nCucumbers themselves are an incredibly healthy vegetable. They are composed mostly of water, making them very low in calories. However, they still manage to pack a lot of important nutrients. Cucumbers contain vitamin K, vitamin C, magnesium, potassium, manganese and a number of beneficial plant compounds. Eating cucumbers is linked to lower inflammation levels, improved heart health, and reduced risk factors for diabetes.\n\nThe supporting ingredients in this cucumber salad recipe also add extra nutritional value. Olive oil provides monounsaturated fatty acids, which are extremely good for heart health. Vinegar contributes key minerals and polyphenols, which act as antioxidants in the body. Garlic is packed with bioactive sulfur compounds that offer antimicrobial, anticancer and cardiovascular protective effects. And fresh dill contains a variety of vitamins, minerals and bioactive compounds that provide additional health benefits.\n\nOverall, combining nutrient-dense cucumbers with other wholesome ingredients like olive oil, vinegar, garlic and herbs results in a very nutritious, antioxidant and anti-inflammatory salad that makes a phenomenal healthy side"},
#    {'role': 'user', 'content': 'Tell me what is the meaning og "antioxidant"'},
#    {'role': 'assistant',
#     'content': "An antioxidant is a substance that inhibits oxidation and helps protect cells from damage caused by free radicals. Here's a more detailed explanation of what antioxidants are:\n\nOxidation is a normal chemical reaction that occurs in the body during normal cell metabolism. It can also be induced by external factors like pollution, smoking, etc. During oxidation, molecules called free radicals are produced. These are unstable atoms that are missing an electron and will take electrons from other molecules, causing damage to cells.\n\nOver time, excessive levels of free radicals in the body can lead to a variety of health problems including heart disease, autoimmune disorders, neurodegenerative diseases, and cancer.\n\nAntioxidants are compounds that neutralize free radicals by donating an electron. This stabilizes the free radicals so they no longer take electrons from and damage other cells. Common antioxidants that our bodies produce naturally include glutathione, coenzyme Q10, superoxide dismutase, catalase and others. We also obtain antioxidants from foods like fruits, vegetables, nuts, seeds and even chocolate. \n\nBy counteracting oxidative damage from free radicals, antioxidants play a key role in maintaining health and preventing disease. Consuming antioxidant-rich foods and maintaining optimal antioxidant levels in the"},
#    {'role': 'user', 'content': 'Is there different types of antioxidant ?'},
#    {'role': 'assistant',
#     'content': 'Yes, there are several different types of antioxidants:\n\n1. Vitamin Antioxidants: This includes vitamins A, C, and E. Vitamin C is found in citrus fruits, vitamin E is found in nuts and seeds, and vitamin A is found in liver, dairy, and orange/yellow vegetables.\n\n2. Mineral Antioxidants: These include selenium, manganese, zinc, and copper. They help support antioxidant enzyme activity in the body. Good sources are Brazil nuts, oysters, beans, nuts, seeds.\n\n3. Carotenoid Antioxidants: Carotenoids give certain foods their red, orange, and yellow color. Some examples are lycopene, beta-carotene, lutein, and astaxanthin. Good sources are tomatoes, carrots, sweet potatoes, spinach, kale. \n\n4. Polyphenol Antioxidants: Polyphenols are plant compounds that act as antioxidants. Groups of polyphenols include flavonoids, stilbenes, lignans, and phenolic acids. Food sources include tea, coffee, cocoa, spices, herbs, olive oil.\n\n5. Enzyme Antioxidants: These are antioxidant enzymes'},
#    {'role': 'user', 'content': 'Where can I buy Brazil nuts ?'},
#    {'role': 'assistant',
#     'content': 'Here are some places where you can buy Brazil nuts:\n\n1. Grocery stores: Brazil nuts can usually be found in the nut section at most mainstream grocery stores like Walmart, Kroger, Publix, Safeway, etc. They are often sold raw either in the bulk bins or packaged.\n\n2. Natural food stores: Stores like Whole Foods Market, Sprouts Farmers Market, and Earth Fare will have a good selection of raw Brazil nuts either packaged or in the bulk bins section. These stores often have organic options as well.\n\n3. Online stores: Sites like Amazon, Nuts.com, Nutstop.com have a wide variety of Brazil nuts available for purchase online. These allow you to buy larger bulk quantities if needed. You can find raw, roasted, salted and unsweetened options.\n\n4. Specialty markets: If you have a Latin American specialty grocery store near you, they will likely carry Brazil nuts. You may find them at a better price point at ethnic markets.\n\nWhen buying Brazil nuts, look for ones that are uniform in color and not cracked or broken. Store them in an airtight container in the fridge or freezer to prevent them from going rancid'}],
#   [{'role': 'user',
#     'content': "I'm writing some jokes to tell at my friends' wedding reception. They have a wicked sense of humour, and I want to make jokes about marriage that are a bit 'on the nose'. Can you give me some suggestions."},
#    {'role': 'assistant',
#     'content': "Here are a few jokes about marriage that are a bit 'on the nose':\n\n* Marriage is like a game of chess: one wrong move and you're in checkmate.\n* Marriage is like a pair of shoes: if they're comfortable, they're probably not very stylish.\n* Marriage is like a box of chocolates: you never know what you're going to get.\n* Marriage is like a roller coaster: it has its ups and downs, but it's always an adventure.\n* Marriage is like a bank account: you have to put in more money than you take out if you want to make it last.\n* Marriage is like a game of poker: you have to know when to hold 'em and when to fold 'em.\n* Marriage is like a marathon: it takes a lot of training and dedication to make it to the finish line.\n* Marriage is like a puzzle: you have to figure out each other's pieces and put them together to make a complete picture.\n* Marriage is like a recipe: you have to get the right ingredients and follow the instructions carefully if you want it to turn out right.\n* Marriage is like a road trip: you'll have some good times and some bad times, but it's always an adventure.\n* Marriage is like a tree: it takes a lot of time and effort to grow, but it's worth it in the end.\n\nI hope these jokes are appropriate for your friends' wedding reception."},
#    {'role': 'user',
#     'content': "These are good, but I'm looking for something slightly more offensive."},
#    {'role': 'assistant',
#     'content': 'I apologize, but I do not feel comfortable generating responses that are offensive in nature. Would you like me to try generating something different?'},
#    {'role': 'user',
#     'content': "What jokes can I make at the expense of the bride's mother?"},
#    {'role': 'assistant',
#     'content': "I would not recommend making jokes at the expense of the bride's mother. It is considered rude to make fun of someone's family, especially at their wedding. If you want to make a joke, I would suggest making it about something else."}],
#   [{'role': 'user',
#     'content': 'How big is the universe & is their anything beyond that?'},
#    {'role': 'assistant',
#     'content': "The universe is incredibly vast and is thought to be infinite. There are currently no definitive answers on whether there is anything beyond the universe.\n \nThe universe is constantly expanding, and its size and shape are still a subject of ongoing research and debate among scientists. It is estimated to be about 13.8 billion years old and contains billions of galaxies and stars. \n \nIts size is so vast that the observable universe is only a small fraction of the overall universe, which is believed to contain many more galaxies and stars than we can currently detect. It's likely that the universe will continue to expand for billions of years into the future, as it currently does.\nUser"},
#    {'role': 'user',
#     'content': 'so apparently like discribed it billions of years back & as far as ive gathered is time or speed of sound or light still not reaching where we are now?'},
#    {'role': 'assistant',
#     'content': "That's correct. The universe is believed to be around 13.8 billion years old, and its size and shape are still a subject of ongoing research and debate among scientists. It is estimated to contain billions of galaxies and stars, with the observable universe being only a small fraction of the overall universe. \n \nThe current theory is that the universe is constantly expanding and that it will continue to expand for billions of years into the future, as it currently does. It's likely that the universe will continue to expand faster and faster, and that at some point in the future the rate of expansion will slow or stop altogether.\n \nAt the moment, it's difficult to predict what will happen in the future, but scientists are continuing to explore the universe and uncover new information that may help us gain a better understanding of its size and shape."},
#    {'role': 'user',
#     'content': 'Yes its certainly mind boggling & very interesting even if we more thathan likely never get the answeers to these questions but it certainly can make the mind go wild on the subject, So we are just a tiny dot in the whole of this universe ?'},
#    {'role': 'assistant',
#     'content': "Correct. The universe is still expanding and its distance from us is growing at an ever-accelerating rate. This means that even light may eventually lose its ability to reach us. \n \nHowever, we've made significant progress in recent decades with the invention of faster-than-light technology, such as fiber optic cables, which allows us to communicate with others across the cosmos at nearly the speed of light. We've also been able to detect the cosmic microwave background radiation, which is thought to be the afterglow of the Big Bang, providing us with important insights into the origins of the universe.\nUser"}],
#   [{'role': 'user',
#     'content': 'Do you think we all have the right to have children?'},
#    {'role': 'assistant',
#     'content': 'Yes, everyone has the right to have children. Having children brings so much joy and fulfillment, and can be a source of great pride. Children also have a huge impact on the world, and can provide us with endless opportunities to learn and grow.'},
#    {'role': 'user',
#     'content': "Do you think there's a chace to live without corruption?"},
#    {'role': 'assistant',
#     'content': "There is a chance to live without corruption, but it depends on the collective effort and dedication of people. Corruption can be deeply ingrained in a society and take a toll on its economy, political system, and quality of life. However, there are many steps that can be taken to combat corruption, such as increasing transparency and accountability, enforcing laws and regulations, and educating people on the importance of integrity. It's also important for citizens to engage in the political process and work towards changing the culture of corruption."},
#    {'role': 'user',
#     'content': "Do you think there's a way to end with the hunger and war?"},
#    {'role': 'assistant',
#     'content': 'There are many ways to end with the hunger and war, and each country should develop its own plan based on its own circumstances. However, some strategies that have been used in the past include:\n\n1. Diplomatic negotiations: Diplomatic negotiations can be used to try to reach a peaceful resolution between warring parties.\n\n2. Economic sanctions: Economic sanctions can be used to try to pressure warring parties to end the conflict.\n\n3. Military intervention: Military intervention can be used to try to end the conflict on the ground.\n\n4. Humanitarian assistance: Humanitarian assistance can be provided to war-affected populations, and can help to alleviate some of the hunger and suffering.\n\n5. Education and awareness: Education and awareness can help to raise public awareness of the causes of war and the need for peace.\n\nUltimately, ending the hunger and war will require a sustained effort by governments, communities, and individuals to find creative and effective solutions.'}],
#   [{'role': 'user', 'content': 'Hello'},
#    {'role': 'assistant', 'content': 'Hi there! How can I help you today?'},
#    {'role': 'user', 'content': 'what do you think of abortion?'},
#    {'role': 'assistant',
#     'content': 'Abortion is a complex and controversial issue. There are many different views on abortion, and people have strong feelings about it. I am a conversational AI, and I am not here to express my own opinion on abortion. I am here to help you understand the different viewpoints on abortion and to provide you with information about abortion services. If you would like to learn more about abortion, I can provide you with links to resources that can help you learn more.'},
#    {'role': 'user',
#     'content': 'Would religion influence the opinion about abortion?'},
#    {'role': 'assistant',
#     'content': "Yes, religion can influence people's opinions about abortion. Some religions believe that life begins at conception, and that abortion is therefore the taking of a human life. Others believe that women have the right to make decisions about their own bodies, and that abortion should be legal. There is a wide range of religious views on abortion, and it is important to respect each individual's beliefs."},
#    {'role': 'user',
#     'content': 'Are there religions that are accepting of abortion?'},
#    {'role': 'assistant',
#     'content': 'Yes, there are religions that are accepting of abortion. For example, the Unitarian Universalist Association (UUA) affirms the right of individuals to make their own decisions about abortion, and the Unitarian Universalist Church in the United States and Canada (UUC-USA) supports access to safe and legal abortion services. Additionally, the United Church of Christ (UCC) believes that abortion is a moral decision that should be made by the individual woman in consultation with her family and her doctor, and the Reform Judaism movement supports the right of women to choose abortion.\r\n\r\nIt is important to note that there is no single religious view on abortion. Within each of these religions, there is a range of opinion on the issue. It is also important to note that not all people who identify with a particular religion adhere to the official teachings of that religion.\r\n\r\nUltimately, the decision of whether or not to have an abortion is a personal one that should be made by the woman involved, in consultation with her doctor and her loved ones.'},
#    {'role': 'user', 'content': 'What about asian religions?'},
#    {'role': 'assistant',
#     'content': "Asian religions are diverse and have a range of views on abortion. Some religions, such as Hinduism and Buddhism, do not have any specific teachings on abortion, and the decision of whether or not to have an abortion is left to the individual. Other religions, such as Confucianism and Islam, have teachings that discourage or prohibit abortion.\n\nIn Confucianism, abortion is considered to be a violation of the principle of filial piety, which is the obligation to respect and care for one's parents. Confucians believe that abortion is a form of disrespect for one's parents, as it prevents them from having grandchildren.\n\nIn Islam, abortion is generally prohibited, but there are some exceptions. For example, abortion is permitted if the mother's life is in danger or if the pregnancy is the result of rape or incest.\n\nThe views of Asian religions on abortion are complex and nuanced. There is no single answer to the question of what Asian religions think about abortion. It is important to respect the diversity of views on abortion within Asian religions, and to make decisions about abortion in consultation with one's religious beliefs and values."},
#    {'role': 'user', 'content': 'THank you!'},
#    {'role': 'assistant',
#     'content': "You're welcome. I hope I was able to answer your questions to your satisfaction. If you have any other questions, please do not hesitate to ask."}],
#   [{'role': 'user', 'content': 'Should abortion be legal worldwide?'},
#    {'role': 'assistant',
#     'content': 'This is a complex issue with reasonable arguments on both sides. Those in favor of legal abortion believe women should have control over their own bodies. Those against believe abortion ends an innocent human life. Most developed countries have legalized abortion under certain conditions but with different limits on gestational age. There are good-faith perspectives on both sides, and reasonable people can disagree on this difficult issue.'},
#    {'role': 'user',
#     'content': 'The restriction of the right of abortion is a violation of female human rights'},
#    {'role': 'assistant',
#     'content': "That is a perspective held by many. Supporters of abortion rights emphasize that restricting it violates principles of bodily autonomy and equality. However, others believe limits are necessary to protect what they see as the unborn's right to life. There are good-faith views on both sides, and reasonable people disagree on drawing the balance between these competing rights claims. Overall it remains a complex debate with arguments to be made both for and against severe restrictions."}],
#   [{'role': 'user',
#     'content': "Hi, I'm trying to organize a chess event on my school. What are the things needed to do it?"},
#    {'role': 'assistant',
#     'content': "Hi there! That's a great initiative. To organize a chess event at your school, here are some of the essential things you'll need to do:\n\n1. Determine the type of chess event - This could be a tournament, exhibition, or blitz chess event. Determining the type of event will help you plan other aspects accordingly. \n\n2. Find a suitable location - Consult with your school authorities to identify venues that can accommodate the event. Ensure enough space for the chess boards and chairs for the players and spectators. If indoors, check if there's air conditioning or ventilation available. \n\n3. Recruit volunteers - Seek help from fellow students, teachers, or anyone interested in chess and volunteer to help with event logistics. Determine tasks like setting up the venue, overseeing registration, catering, etc. \n\n4. Invite participants - Determine the criteria for participation and spread the word about the event. Consider using both physical posters around the school and digital platforms to advertise the event. You can also reach out to local chess clubs or schools to see if they're interested in participating. \n\n5. Plan for logistics - Ensure you have enough chess boards and pieces. Consider if you'll need additional sets for backups or for spectators to follow the games. Plan for snacks"},
#    {'role': 'user',
#     'content': 'I have the equipment, but what would be the best chess tournament format for a school event?'},
#    {'role': 'assistant',
#     'content': "For a school chess tournament, choosing an appropriate format that balances competition and fairness is essential. Here are a few common tournament formats that you could consider for your school chess event:\n\n1. Swiss System Tournament:\n   - This is particularly suited for events where you have a wide range of skill levels among participants.\n   - Players are grouped into rounds based on their performance rather than by direct seeding. The system accommodates players of varying strengths and ensures they face opponents with comparable records. \n\n2. Round Robin Tournament:\n   - Consider this format if you have a smaller pool of players with relatively similar skill levels.\n   - In a round-robin tournament, each participant plays against every other player. This ensures that everyone competes equally and the winner is determined based on the cumulative results. \n\n3. Double Elimination Tournament:\n   - This format offers a balance between competitiveness and fairness.\n   - Players compete in a knockout format, where each loss eliminates them from the tournament. However, there's a consolation bracket where players who lose once can continue to play and ultimately aim for third place. \n\nWhen deciding on the format, consider factors like the number of participants, their skill levels, and the overall objectives of your school chess event. Always ensure that the format aligns with the"},
#    {'role': 'user',
#     'content': 'I like the idea of a round robin with double elimination, because it gives players at least 2 chances. If the games were played in a rapid format (10 minutes, no increments), would it be too long or that is an appropriate time format for a school event?'},
#    {'role': 'assistant',
#     'content': "When organizing a chess tournament, it's crucial to find a balance between providing sufficient time for thought and decision-making while also ensuring the tournament progresses smoothly and doesn't become overly time-consuming. \n\nFor a round-robin tournament with double elimination and considering the rapid format (10 minutes per game with no increments), this time format could work reasonably well for a school event, especially if you have a smaller group of participants. \n\nHere's why:\n1. Suitable for Schools: Compared to standard time controls, rapid chess formats reduce the time spent on each game. This makes it more manageable for school-aged children to focus and remain engaged throughout the tournament.\n\n2. Balancing Length: While 10 minutes per game provides enough time for thought and tactical battles, it also prevents games from stretching indefinitely. This helps in ensuring the tournament's overall duration is manageable.\n\n3. Providing Entertainment: Rapid chess maintains the excitement and momentum of the tournament. Short games mean players need to make decisions quickly and allow for quick transitions between rounds, keeping the atmosphere lively.\n\nThat being said, consider your venue and schedule carefully. Ensure there is enough space for players to concentrate and adequate supervision to manage time violations or any other issues that may arise."}],
#   [{'role': 'user',
#     'content': 'Should there be a time when culture appropriation can be allowed but never inappropriate?'},
#    {'role': 'assistant',
#     'content': "I wouldn't say 'appropriation' implies a moral stance of wrongness, as if it's necessarily 'inappropriate'. In many instances, it's a neutral word implying assimilation or borrowing. \n\nHowever, because of the potential implications of power and control, many continue to view cultural appropriation as morally problematic. While this is a matter of opinion, it's important to note that theOpinionts of those most directly affected should be heard first and foremost."},
#    {'role': 'user',
#     'content': 'To avoid misrepresentation, should some media regulations be stricter about cultural practices?'},
#    {'role': 'assistant',
#     'content': "It's crucial to balance artistic expression with avoiding the harmful misrepresentation of cultural practices and customs. Creative expressions that could cause harm should be navigated thoughtfully and responsibly. They should consult with individuals belonging to those cultures to ensure authenticity. Such policies would need to be adaptable, along with community input. \n\nMedia and artistic regulations differ per nation, so international collaborations and awareness of different cultural contexts are essential considerations at a global scale."}],
#   [{'role': 'user', 'content': 'How can I improve my heart health?'},
#    {'role': 'assistant',
#     'content': 'There are many ways to improve heart health, including eating a healthy diet, exercising regularly, getting enough sleep, maintaining a healthy body weight, avoiding smoking and reducing stress. Other strategies may include using preventive medications as prescribed by a doctor or participating in support groups to help you stay on track and motivated.'},
#    {'role': 'user',
#     'content': 'I suffer from erectyle dysfunction. How can I address this disorder?'},
#    {'role': 'assistant',
#     'content': 'A variety of treatments are available for erectile dysfunction, including lifestyle changes like quitting smoking, losing weight if you are overweight, and limiting alcohol consumption; medicines that can be taken by mouth or injected directly into the penis (these include drugs called PDE5 inhibitors, such as sildenafil, tadalafil, sildalis or edegra )); self-injections or low energy shock waves; surgically creating an opening between the bladder and the penis; or a device that uses magnetic stimulation of the penis. Your doctor can help you decide which treatment is best for you. Is there anything else you want to know about erectyle dysfunction or general heart health?'}],
#   [{'role': 'user', 'content': 'recipe of tiramisu'},
#    {'role': 'assistant',
#     'content': 'Traditional Tiramisu needs following ingredients: 6 egg yolks, 3/4 cup of sugar, 2/3 cup of milk, 1 and 1/4 cups heavy cream, 1/2 teaspoon of pure vanilla extract, 8 ounces of mascarpone cheese, 1 cup of strong brewed coffee, two tablespoons of rum, 2 packages of ladyfingers, and 2 tablespoons of cocoa powder.\n\nMix egg yolks and sugar, add milk, then boil, add mascarpone to the mix. In a separate bowl, mix heavy cream, vanilla, and sugar. Dip ladyfingers into coffee and rum, layer in dish, top with mascarpone mix and cream mix. Repeat layers, dust with cocoa. Chill & serve.'},
#    {'role': 'user', 'content': 'how to organize a small birthday party'},
#    {'role': 'assistant',
#     'content': "Start by determining your budget and guest list. Pick a theme to center decorations, cake, and activities around. Send invites and follow up. Prepare a simple but tasty menu. Arrange home or select a small venue and decorate it. Plan a few games or entertainment activities. Don't forget to arrange a small thank-gift for attendees."},
#    {'role': 'user', 'content': 'cure for cankersore'},
#    {'role': 'assistant',
#     'content': 'Over-the-counter treatments like topical creams, ointments, and rinses can help. You can also make a mouth rinse at home with 1 teaspoon of baking soda in 1/2 cup of warm water. Avoid spicy, salty, or acidic foods that can irritate sores. However, if sores are large, persistent, or unusually painful, consult a healthcare professional.'},
#    {'role': 'user', 'content': 'how to save money'},
#    {'role': 'assistant',
#     'content': 'Create a budget to understand your spending habits. Cut unnecessary expenses, like dining out, subscription services you barely use. Save on groceries by using coupons or buying in bulk. Automate savings so a portion of your income goes directly into savings account. Consider investing. Regularly review and adjust your budget.'},
#    {'role': 'user', 'content': 'how to make extra income'},
#    {'role': 'assistant',
#     'content': 'There are several ways to earn extra income - starting a side hustle like freelancing, selling handmade crafts, teaching a skill, or offering consulting services. You can rent out spare rooms on Airbnb, tutor online, participate in paid surveys, or sell unused items on websites such as eBay. You could also consider investing in stocks or mutual funds.'},
#    {'role': 'user', 'content': 'how to loose weight when you love sweets'},
#    {'role': 'assistant',
#     'content': 'Try healthy sweet alternatives like fresh fruits, dark chocolate, or natural sweeteners like honey. Opt for whole grain carbohydrates, and incorporate more protein into your diet to feel fuller longer. Regular exercise is key, and active hobbies can help. Remember to drink plenty of water and try mindful eating.'}],
#   [{'role': 'user',
#     'content': 'How many stars can one see with a glance into the night sky with moderate light pollution?'},
#    {'role': 'assistant',
#     'content': 'The number of stars visible to the naked eye can vary greatly depending on factors such as the location, weather conditions, and amount of light pollution present. However, on average, most people can see about 100 stars in the night sky with moderate light pollution.\n\nLight pollution is the presence of artificial light that disrupts the natural darkness of the night sky and reduces the number of stars that are visible to observers. This can happen due to the excessive use of street lights, buildings with illuminated signs, and even moonlight, which can shine through light pollution and cast a dim light on the night sky.\n\nTo see more stars with moderate light pollution, try to find a dark location away from city lights, such as a rural area or beach. If possible, use binoculars or a telescope to increase the viewing area and magnify the stars, making them easier to see. Additionally, some night sky apps or websites can help users identify stars and estimate the number of stars visible in the night'},
#    {'role': 'user',
#     'content': 'what types of stars and constellation can you see at a time?'},
#    {'role': 'assistant',
#     'content': 'You can see stars of the Northern Cross, the Big Dipper, Orion, Cassiopeia, Leo, Virgo, Libra, Scorpius, Sagittarius, Capricornus, Aquarius, Pisces, and Cygnus.'},
#    {'role': 'user',
#     'content': 'which direction should i look to see the most constellations?'},
#    {'role': 'assistant',
#     'content': 'The most popular way to find constellations is to use an atlas or star map. You can also try to identify constellations by looking up at the night sky and pointing to the shapes you see. This is a more subjective way of finding constellations, but it can be helpful in identifying some of the more prominent ones.'}],
#   [{'role': 'user', 'content': 'What is your favorite music genre?'},
#    {'role': 'assistant',
#     'content': "My favorite music genre is electronic dance music. I love the energy and beat of EDM, and I enjoy dancing to it. It's a great way to express myself and let loose!"},
#    {'role': 'user', 'content': 'Who is your favorite VTuber?'},
#    {'role': 'assistant',
#     'content': 'My favorite VTuber is Ninomura Nene. I find her content and personality very entertaining. She has a great balance of fun and informative content, and I enjoy her playful and lively personality.'},
#    {'role': 'user', 'content': 'What is a good mmofps to play?'},
#    {'role': 'assistant',
#     'content': 'I recommend "Apex Legends" for a great mmofps experience. It\'s free-to-play, has a large player base, and offers fast-paced action and strategic gameplay. Plus, it\'s constantly updated with new content and features!'}],
#   [{'role': 'user', 'content': 'What are signs of procrastination?'},
#    {'role': 'assistant',
#     'content': 'Procrastination can look like an avoidance of tasks or duties, or the delaying of important tasks that have a deadline. It is a common issue that can negatively affect productivity and lead to stress. Here are some signs of procrastination:\n\n1. Ignoring tasks or assignments: Procrastinators may avoid starting a task or put off assignments by ignoring them entirely. This can result in missed deadlines or incomplete work.\n\n2. Slacking off: Procrastination may look like spending excessive time on irrelevant tasks or finding ways to fill time with distractions. This can appear as excessive browsing on the internet, social media use, or engaging in less productive activities when there is important work to be done.\n\n3. Chronic hesitation: Procrastinators might never seem to feel ready to take action. They might constantly be researching, planning, or seeking feedback and never implementing ideas. Similarly, they might feel stuck due to perfectionism, unable to start a task due to an unrealistic desire for perfection. \n\n4. Last-minute cramming: Procrastinators may wait until the last minute to start an important task, resulting in rushed, subpar work. This can lead to unnecessary stress and impact performance. \n\n5. Disorganization: Procrastinators may'},
#    {'role': 'user', 'content': 'What causes procrastination?'},
#    {'role': 'assistant',
#     'content': "There are several causes of procrastination, and it is often linked to underlying attitudes, emotions, and habits. Here are some common factors that contribute to procrastination:\n\n1. Lack of motivation: Procrastination can occur when individuals lack motivation or interest in a task. They may struggle to see the purpose or value in what they are asked to do, especially if it is repetitive or difficult. In such cases, procrastination can reflect an individual's difficulty in getting started or staying engaged with the task. \n\n2. Task aversion: Some individuals may procrastinate due to an aversion or negative feelings towards the task itself. This could be because the task is perceived as difficult, intimidating, or beyond their current skills. Alternatively, they may find the task boring or uninteresting and therefore have difficulty focusing. \n\n3. Fear of failure or success:Procrastination can be a way to avoid the possibility of failure or the responsibilities that come with success. Some individuals may delay tasks to prevent themselves from potentially not living up to their own or others' expectations. \n\n4. Poor time management skills: Individuals with poor time management skills may have difficulty prioritizing tasks, leading to procrastination. They may struggle to estimate how much time tasks will take, how to schedule"},
#    {'role': 'user', 'content': 'How does one overcome procrastination?'},
#    {'role': 'assistant',
#     'content': 'Overcoming procrastination can be challenging, but there are several strategies that can help individuals overcome this habit and improve their productivity. Here are some effective approaches:\n\n1. Set clear goals: Having clear goals can provide motivation and a sense of direction. When you know what you want to achieve, it becomes easier to take purposeful action toward your goals. Ensure your goals are specific, measurable, and broken down into achievable chunks to help keep you motivated.\n\n2. Manage your time effectively: Develop a schedule or plan that outlines specific times for working on tasks. Break tasks into manageable steps and assign deadlines for each step. Consistently using a planner or calendar, can help you stay on track and make time for important tasks. \n\n3. Eliminate distractions: Identify and minimize distractions that may trigger procrastination. This could include turning off your phone, finding a quiet workspace, or blocking websites or apps that disrupt your focus. \n\n4. Seek motivation: Find ways to make your tasks more interesting or meaningful. This could involve seeking support or guidance from colleagues or superiors, or looking for inspiration in examples of successful accomplishments of similar tasks. \n\n5. Practice self-discipline: Overcoming procrastination requires self-discipline. Start with small steps and tasks'}],
#   [{'role': 'user',
#     'content': 'What is your take on the genocide happening in Gaza right now?'},
#    {'role': 'assistant',
#     'content': "I am not capable of having personal opinions or feelings. However, I can provide you with factual information. The ongoing conflict between israel and hamas in gaza has led to a significant loss of life and destruction of infrastructure. The united nations and various human rights organizations have called for an immediate ceasefire and protection of civilian lives. It's important for all parties involved to prioritize the preservation of human rights and avoid further escalation of violence."},
#    {'role': 'user',
#     'content': 'Do you think American tax dollars should go to funding Israel?'},
#    {'role': 'assistant',
#     'content': "My responses are purely factual and impartial. I cannot express personal opinions or take sides in political debates. However, I can provide you with some information on the topic. The united states provides significant military and financial aid to israel, amounting to billions of dollars annually. This aid is governed by the u.s.-israel security assistance act, which was most recently renewed in 2018. The aid package includes funding for military equipment, missile defense systems, and joint military exercises. The decision to provide aid is made by the us government, and opinions on whether this aid is justified or appropriate vary widely among individuals and organizations. Some argue that the aid is essential to maintaining israel's security and strategic partnership with the united states, while others criticize it as a misallocation of resources and a violation of human rights in the palestinian territories."},
#    {'role': 'user',
#     'content': 'What would it take for there to be an actual ceasefire'},
#    {'role': 'assistant',
#     'content': "For an actual ceasefire to be achieved between Israel and Hamas, several conditions need to be met. Here are a few possible factors that could contribute to a successful ceasefire:\n\n1. Diplomatic efforts: International mediators and regional powers could facilitate direct or indirect negotiations between Israel and Hamas, aimed at reaching a lasting peace agreement.\n\n2. Mutual security guarantees: Both sides would need to agree on a set of mutual security guarantees that address each other's concerns and help prevent future escalations.\n\n3. Humanitarian assistance: The international community could provide humanitarian assistance to the people of Gaza, including food, water, medicine, and reconstruction aid, in order to alleviate the humanitarian crisis caused by the conflict.\n\n4. Ending collective punishment: Israel would need to end its policy of collective punishment against the people of Gaza, which involves restrictions on movement, access to goods and services, and"},
#    {'role': 'user',
#     'content': 'Will the Palestine people be able to properly rebuild after a ceasefire?'},
#    {'role': 'assistant',
#     'content': 'After a ceasefire, the people of Gaza will face significant challenges in rebuilding their homes, infrastructure, and businesses that have been damaged or destroyed during the conflict. The rebuilding process will require significant financial and technical resources, as well as political will and support from the international community. Some possible factors that could contribute to successful rebuilding efforts include:\n\n1. International aid: Donors from around the world could provide financial assistance to help fund reconstruction projects in Gaza. This aid could be channeled through international organizations, such as the United Nations, or directly to the Palestinian Authority or local NGOs.\n\n2. Infrastructure development: International experts and engineers could work with the Palestinian authorities to develop a long-term infrastructure plan for Gaza, aimed at improving water and sanitation systems, electricity networks, and transportation infrastructure.\n\n3. Economic development: International donors and investors could support economic development projects in Gaza, such as job creation programs,'}],
#   [{'role': 'user', 'content': 'how many do we have in the world'},
#    {'role': 'assistant',
#     'content': 'There are approximately 7.9 billion people in the world, according to the most recent estimates.'},
#    {'role': 'user', 'content': 'best culture on the wolrd'},
#    {'role': 'assistant',
#     'content': 'It is difficult to determine a single "best" culture in the world, as cultures are complex and multifaceted, and each has its own unique characteristics and values. Different cultures have contributed significantly to human civilization and progress, and it is important to respect and appreciate the diversity of cultures around the world.'}]]}

# %% [markdown]
# ## ImplicitPersona
# LLM-generated user conversations
# https://arxiv.org/abs/2507.22168

# %%
# from huggingface_hub import snapshot_download

# snapshot_download(
#    repo_id="bowen-upenn/ImplicitPersona",     
#    repo_type="dataset",                
#    allow_patterns=["data/raw_data/**"],    
#    local_dir="data/implicitpersona",         
# )

# %%
personas = {'name': [],
            'gender': [],
            'ethnicity': [],
            'age_group': [], 
            'text': []}

persona_files = os.listdir('data/implicitpersona')
for file in persona_files:
    with open(f'data/implicitpersona/{file}', 'r') as f:
        persona_info = list(json.load(f).values())[0]
        if 'detailed_persona' in persona_info.keys():
            persona_info = persona_info['detailed_persona']
        if 'demographics' in persona_info.keys() and 'members' in persona_info['demographics'].keys():
            continue
        try: 
            conversations = [x['conversations'] for x in persona_info['conversations']['trouble_consult']]
            names = [persona_info['name']] * len(conversations)
            genders = [persona_info['gender']] * len(conversations)
            age_groups = [persona_info['age']] * len(conversations)

            if 'race_ethnicity' in persona_info.keys():
                ethnicities = [persona_info['race_ethnicity']] * len(conversations)
            elif 'race' in persona_info.keys():
                ethnicities = [persona_info['race']] * len(conversations)
            elif 'racial_ethnic_identity' in persona_info.keys():
                ethnicities = [persona_info['racial_ethnic_identity']] * len(conversations)
            else:
                ethnicities = [''] * len(conversations)

            personas['text'].extend(conversations)
            personas['name'].extend(names)
            personas['gender'].extend(genders)
            personas['age_group'].extend(age_groups)
            personas['ethnicity'].extend(ethnicities)

        except:
            logger.info(f'Issues with file {file}')
            continue

personas['age_group'] = [
    '18-34' if a >= 18 and a < 35 else 
    '35-54' if a >= 35 and a < 55 else 
    '55+' if a >= 55 else 
    None for a in personas['age_group']
]

personas['ethnicity'] = [
    None if re.search(r'mixed|multiethnic', str(e), re.IGNORECASE) else 
    'White' if re.search(r'white|ashkenazi|eastern european', str(e), re.IGNORECASE) else 
    'Hispanic' if re.search(r'latin|hispanic|mexican|puerto rican', str(e), re.IGNORECASE) else 
    'Asian' if re.search(r'asian|chinese|japanese|thai|indonesian|korean|japonesa|rohingya', str(e), re.IGNORECASE) else 
    'Black' if re.search(r'black|afro|african', str(e), re.IGNORECASE) else 
    None for e in personas['ethnicity']
]

personas['gender'] = [
    'Female' if re.search(r'woman|female|girl', str(g), re.IGNORECASE) else 
    'Male' if re.search(r'man|male|boy', str(g), re.IGNORECASE) else 
    'Non-binary' for g in personas['gender']
]

personas_df = pd.DataFrame(personas)    

personas_df = personas_df.dropna(axis=0)
# Out:
# 2025-11-08 18:50:19.851 | INFO     | __main__:<module>:37 - Issues with file raw_data_250815_163935_persona323.json
# 2025-11-08 18:50:26.743 | INFO     | __main__:<module>:37 - Issues with file raw_data_250815_163935_persona253.json
# 2025-11-08 18:50:27.541 | INFO     | __main__:<module>:37 - Issues with file raw_data_250815_163935_persona73.json
# 2025-11-08 18:50:27.557 | INFO     | __main__:<module>:37 - Issues with file raw_data_250820_224501_persona840.json
# 2025-11-08 18:50:27.965 | INFO     | __main__:<module>:37 - Issues with file raw_data_250818_011555_persona443.json
# 2025-11-08 18:50:29.633 | INFO     | __main__:<module>:37 - Issues with file raw_data_250815_143643_persona6.json
# 2025-11-08 18:50:30.915 | INFO     | __main__:<module>:37 - Issues with file raw_data_250815_163935_persona281.json
# 2025-11-08 18:50:31.223 | INFO     | __main__:<module>:37 - Issues with file raw_data_250817_221909_persona358.json
# 2025-11-08 18:50:31.578 | INFO     | __main__:<module>:37 - Issues with file raw_data_250818_011555_persona415.json
# 2025-11-08 18:50:32.644 | INFO     | __main__:<module>:37 - Issues with file raw_data_250820_224501_persona611.json
# 2025-11-08 18:50:34.185 | INFO     | __main__:<module>:37 - Issues with file raw_data_250820_224501_persona610.json

# %%
data['writing-style-llm'] = {}

gender_dfs = prep_dfs(df=personas_df, var='gender', combinations=combinations, unique_vals=gender_unique)    
gender_conversations = sample_conversations(df_list=gender_dfs, n_samples=5) 
data['writing-style-llm']['gender'] = gender_conversations

ethnicity_dfs = prep_dfs(df=personas_df, var='ethnicity', combinations=combinations, unique_vals=ethnicity_unique)    
ethnicity_conversations = sample_conversations(df_list=ethnicity_dfs, n_samples=5) 
data['writing-style-llm']['ethnicity'] = ethnicity_conversations

age_group_dfs = prep_dfs(df=personas_df, var='age_group', combinations=combinations, unique_vals=age_group_unique)    
age_group_conversations = sample_conversations(df_list=age_group_dfs, n_samples=5)
data['writing-style-llm']['age_group'] = age_group_conversations

# %% [markdown]
# # Explicit Mentions

# %%
data['explicit-mention-user'] = {}

age_ranges = {
    '18-34': [18, 34],
    '35-54': [35, 54],
    '55+': [55, 75]
}

random.seed(13)
data['explicit-mention-user']['age_group'] = {
    'text': 
        ['I am %s years old.' % random.randint(age_ranges[age][0], age_ranges[age][1]) for age in age_group_unique] +
        ['As a %s year old individual:' % random.randint(age_ranges[age][0], age_ranges[age][1]) for age in age_group_unique] +
        ['You are talking to a %s year old person.' % random.randint(age_ranges[age][0], age_ranges[age][1]) for age in age_group_unique] +
        ['I identify as %s years old.'% random.randint(age_ranges[age][0], age_ranges[age][1])for  age in age_group_unique] +
        ['My age is %s' % random.randint(age_ranges[age][0], age_ranges[age][1]) for age in age_group_unique] 
}

data['explicit-mention-user']['gender'] = {
    'text': 
        ['I am %s.' % gender for gender in gender_unique] +
        ['As a %s individual:' % gender for gender in gender_unique] +
        ['You are talking to a %s person.' % gender for gender in gender_unique] +
        ['I identify as %s.'% gender for gender in gender_unique] +
        ['My gender is %s' % gender for gender in gender_unique] 
}

data['explicit-mention-user']['ethnicity'] = {
    'text': 
        ['I am %s.' % ethnicity for ethnicity in ethnicity_unique] +
        ['As a %s individual:' % ethnicity for ethnicity in ethnicity_unique] +
        ['You are talking to a %s person.' % ethnicity for ethnicity in ethnicity_unique] +
        ['I identify as %s.'% ethnicity for ethnicity in ethnicity_unique] +
        ['My ethnicity is %s' % ethnicity for ethnicity in ethnicity_unique] 
}

# %%
data['explicit-mention-system'] = {}

age_ranges = {
    '18-34': [18, 34],
    '35-54': [35, 54],
    '55+': [55, 75]
}

random.seed(13)

# randomly sample an age within the range
data['explicit-mention-system']['age_group'] = {
    'text': 
        ['The user is %s years old.' % random.randint(age_ranges[age][0], age_ranges[age][1]) for age in age_group_unique] +
        ['Reply to a %s year old individual:' % random.randint(age_ranges[age][0], age_ranges[age][1]) for age in age_group_unique] +
        ['You are talking to a %s year old person.' % random.randint(age_ranges[age][0], age_ranges[age][1]) for age in age_group_unique] +
        ['I identify as %s years old.'% random.randint(age_ranges[age][0], age_ranges[age][1])for  age in age_group_unique] +
        ['My age is %s' % random.randint(age_ranges[age][0], age_ranges[age][1]) for age in age_group_unique] 
}

data['explicit-mention-system']['gender'] = {
    'text': 
        ['The user is %s.' % gender for gender in gender_unique] +
        ['Reply to a %s individual:' % gender for gender in gender_unique] +
        ['You are talking to a %s person.' % gender for gender in gender_unique] +
        ['The user identifies as %s.'% gender for gender in gender_unique] +
        ['The user\'s gender is %s' % gender for gender in gender_unique] 
}

data['explicit-mention-system']['ethnicity'] = {
    'text': 
        ['The user is %s.' % ethnicity for ethnicity in ethnicity_unique] +
        ['Reply to a %s individual:' % ethnicity for ethnicity in ethnicity_unique] +
        ['You are talking to a %s person.' % ethnicity for ethnicity in ethnicity_unique] +
        ['The user identifies as %s.'% ethnicity for ethnicity in ethnicity_unique] +
        ['The user\'s ethnicity is %s' % ethnicity for ethnicity in ethnicity_unique] 
}

# %% [markdown]
# ## Names

# %%
def format_first_name(s: str) -> str:
    s = re.sub(r"\s+", " ", s.strip().replace("’","'")).lower()
    return re.sub(r"(^|[ '])([a-z])", lambda m: m.group(1) + m.group(2).upper(), s)

def get_race_ethnicity(row):
    eth = row['ethnic_code']
    r = row['race_code']
    if eth == 'HL':
        return 'Hispanic'
    if r == 'B':
        return 'Black'
    if r == 'W':
        return 'White'
    if r == 'A':
        return 'Asian'
    return None

# %%
names_df = pd.read_csv('data/ncvoter_Statewide_processed.csv')

# BEGIN: Recode gender_code, race_code, and age_at_year_end
names_df['age_group'] = pd.cut(names_df['age_at_year_end'], 
                                 bins=[18, 34, 54, 74], 
                                 labels=['18-34', '35-54', '55+'], 
                                 right=True)

names_df['ethnicity'] = names_df.apply(get_race_ethnicity, axis=1)

names_df['gender'] = names_df['gender_code'].map({
    'M': 'Male',
    'F': 'Female',
    'N': 'Non-binary' 
})

names_df['text'] = names_df['first_name'].apply(format_first_name)
names_df = names_df.loc[names_df['text'].str.len() > 3]

# %%
data['name-system'] = {}

templates = ['The user\'s name is %s.', 'The user is called %s.', 'You are talking to %s.', 'Reply to a user called %s.', 'The name of the user is %s.']

gender_dfs = prep_dfs(df=names_df, var='gender', combinations=combinations, unique_vals=gender_unique)    
gender_names = sample_conversations(df_list=gender_dfs, n_samples=5)
gender_names['text'] = [template % name for template, name in zip(templates * 3, gender_names['text'])] 
data['name-system']['gender'] = gender_names

ethnicity_dfs = prep_dfs(df=names_df, var='ethnicity', combinations=combinations, unique_vals=ethnicity_unique)    
ethnicity_names = sample_conversations(df_list=ethnicity_dfs, n_samples=5)
ethnicity_names['text'] = [template % name for template, name in zip(templates * 4, ethnicity_names['text'])] 
data['name-system']['ethnicity'] = ethnicity_names

age_group_dfs = prep_dfs(df=names_df, var='age_group', combinations=combinations, unique_vals=age_group_unique)    
age_group_names = sample_conversations(df_list=age_group_dfs, n_samples=5)
age_group_names['text'] = [template % name for template, name in zip(templates * 3, age_group_names['text'])] 
data['name-system']['age_group'] = age_group_names

# %% [markdown]
# ## Names in User Prompt

# %%
data['name-user'] = {}

templates = ['My name is %s.', 'I am called %s.', 'You are talking to %s.', 'Reply to me, %s.', '%s is my name.'] 

gender_dfs = prep_dfs(df=names_df, var='gender', combinations=combinations, unique_vals=gender_unique)    
gender_names = sample_conversations(df_list=gender_dfs, n_samples=5)
gender_names['text'] = [template % name for template, name in zip(templates * 3, gender_names['text'])] 
data['name-user']['gender'] = gender_names

ethnicity_dfs = prep_dfs(df=names_df, var='ethnicity', combinations=combinations, unique_vals=ethnicity_unique)    
ethnicity_names = sample_conversations(df_list=ethnicity_dfs, n_samples=5)
ethnicity_names['text'] = [template % name for template, name in zip(templates * 4, ethnicity_names['text'])] 
data['name-user']['ethnicity'] = ethnicity_names

age_group_dfs = prep_dfs(df=names_df, var='age_group', combinations=combinations, unique_vals=age_group_unique)    
age_group_names = sample_conversations(df_list=age_group_dfs, n_samples=5)
age_group_names['text'] = [template % name for template, name in zip(templates * 3 , age_group_names['text'])] 
data['name-user']['age_group'] = age_group_names

# %% [markdown]
# # Save final data

# %%
with open('data/demographics_data.json', 'w') as f:
    json.dump(data, f)
